# %% [markdown]
# # Classification task on random number generators

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier,GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Importing Dataset

# %%
data = pd.read_csv("/kaggle/input/generator-data/TrainingData.csv")
data
# Out:
#        BID                                          Bitstream  class
# 0        0  1000111010111101101100110111001111001000101111...      1
# 1        1  1101111100101011111111101101010001110110000010...      1
# 2        2  0011001010001010100100011101000111110100101111...      0
# 3        3  1101010110000110100001001100111101000000110001...      1
# 4        4  1010111100001001000101010010111010011101001100...      1
# ...    ...                                                ...    ...
# 1995  1995  1110110011110100001111101111010110011000001110...      0
# 1996  1996  0100010100011110101110000110100101100000011001...      1
# 1997  1997  1100001010100011010001110001010010101010101100...      0
# 1998  1998  0011110000001110101101111110110100010010100011...      1
# 1999  1999  0100000010100101000000011010011011011111011011...      1
#
# [2000 rows x 3 columns]

# %%
X = data['Bitstream'].apply(lambda x: [int(bit) for bit in x]).tolist()
X = np.array(X)

# %%
y = data['class']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# ## Scaling Data

# %%
ss = StandardScaler()

# %%
x_tr_scl = ss.fit_transform(x_train)
x_ts_scl = ss.transform(x_test)

# %% [markdown]
# ## Model Training and Evaluating

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_tr_scl,y_train)
yp = rfc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.48833333333333334

# %%
knc = KNeighborsClassifier()
knc.fit(x_tr_scl, y_train)
yp = knc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.4583333333333333

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc =DecisionTreeClassifier()

dtc.fit(x_tr_scl,y_train)
yp = dtc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.495

# %% [markdown]
# ### Logistic Regression

# %%
lgc = LogisticRegression()

lgc.fit(x_tr_scl,y_train)
yp = lgc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.5066666666666667

# %% [markdown]
# ### Ada Boosting Classifier

# %%
adc = AdaBoostClassifier()

adc.fit(x_tr_scl,y_train)
yp = adc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.515

# %% [markdown]
# ### K Nearest Neighbors

# %%
knc = KNeighborsClassifier()

knc.fit(x_tr_scl,y_train)
yp = knc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.4583333333333333

# %% [markdown]
# ### Support Vector Classifier

# %%
svc = SVC()

svc.fit(x_train,y_train)
yp = svc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.485

# %% [markdown]
# ### Graident Boosting Classifier

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_tr_scl,y_train)
yp = gbc.predict(x_ts_scl)
accuracy_score(yp,y_test)
# Out:
# 0.5166666666666667
